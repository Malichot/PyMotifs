# %% [markdown]
# # Goal:
#
# Explain the canonical label of a work by the motifs within a corpus.
#
#
# # Methodology:
#
# ## Model
# We use a linear classification technique which takes the following form, $\forall i \in [1, n]$:
# $$y_i = \alpha_1 X_{i1} + \alpha_2 X_{i2} + \ldots + \alpha_p X_{ip} + \beta_0C_0 + \ldots + \beta_mC_m = f_{\alpha, \beta}(X, C)$$
# where $y$ indicates the where document $i$ is considered canonical (1) or not (0) and $X_i$ is a vector of features computed from motifs of length $p$ for the document $i$, $C = (C_0, \ldots, C_m)$ is a vector of control variables, and $n$ is the number of documents.
#
# Since the canonical label is defined at the author level within our corpus, we need to add these variables to control for the effects that might influence the use of some motifs within specific writings. Our goal is to find the motifs that explain the canonical label, independently from such effects. For example, in the notebook "0_Pipeline_Motifs" we have found that "le NC de" is highly specific to Balzac in "Le Père Goriot". Maybe this motifs is fully explained by the variable "Balzac" who is considered canonical. Thus, a model that does not control for the author variable might conclude that "le NC de" has a strong influence on the canonical label, while "Balzac" might be the variable explaining the canonical label and not the motif itself.
#
# Thus, we include as dummies the author, gender, and publication period as control variables. That way we will find the motifs that explain the canonical aspect of a writing indepently from the author, gender and publication date, focusing only on linguistic features of the writing.
#
# ### Pre-selection of features
#
# In this notebook, $p$ is very large ($>200K$), thus we introduce a criterion for feature selection before estimating the parameters. Since we know that a token which as a tfidf of 0 corresponds to non-informative tokens, we propose a simple solution solution based on the sparsity of feature $X_{:,j}$. We define the sparsity level as the proportion of 0 in a vector: $\forall j, \operatorname{S}_j = 1/n\sum_i \operatorname{I}\{X_{i,j} = 0\}$. The more sparse the token is in the corpus, the less informative it is, since it is more common to all documents. Then, we simply select the $P$ less sparse features.
#
#
# ## Estimation
#
# We apply the pipeline in order to obtain the motif annotations (or any other token). Then, we compute the $X_i$ which are defined as the TFIDF scores of each motif within each document in the corpus, where a document represents a window of motifs, as stated above.
#
# To fit the model, we simply minimize the Mean Squarred Error as in a classical logistic regression framework. However, in order to select the most important motifs, we apply the L1 regularization which forces non-informative features to have a 0 coefficient.
#
# ## Evaluation
#
#
# To evaluate the model, we split the data in train/test samples where the observations in the test sample come from documents that are not in the train sample. We keep the class distributions in the train and test equal a Finally, we use the accuracy metric on the test set (as classes are balanced).

# %% [markdown]
# # Import librairies

# %%
from gensim import corpora
from gensim import models
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import pandas as pd

from motifs.dataloader import CanonData
from motifs.features import bow_to_matrix
from motifs.utils import filter_token_by_freq

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import time

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import RocCurveDisplay
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder


from motifs.pipeline import Pipeline
from motifs.features import build_tfidf, transform_corpus_to_ngrams
from motifs.utils import build_window_corpus, return_to_text_from_token

# %% [markdown]
# # Load data
#
# - Get metadata
# - Load the 5-grams that were precomputed using a subcorpus of the "canon" corpus.
#     - This subcorpus was built by selecting at most 50 texts at random per period, which are defined in `motifs.dataloader.CanonData`, e.g 1800-1826, 1827-1850, 1851-1869, 1870-1899, 1900-1945, 1946-2024.
#     - We have in total 217 documents
#     - Remove tokens that appear only once in each document in the corpus

# %%
NGRAMS_PATH = "/Users/brunospilak/Documents/Sorbonne/PyMotifs/data_backup/ngrams_canon.csv"
METADATA_PATH = "../data/canon/metadata.csv"

# %%
# Load 5-grams, about 1.6GB in RAM
t1 = time.time()
ngrams = pd.read_csv(NGRAMS_PATH, index_col=0)
t2 = time.time()
print(f"Done in {t2-t1:.2f} secs")
docs = list(set(ngrams.doc.unique()))

# Remove tokens that appear only once, this can take a while since ngrams has more than 15 Million rows
t1 = time.time()
ngrams = filter_token_by_freq(ngrams, 1, groupby="doc")
t2 = time.time()
print(f"Done in {t2-t1:.2f} secs")
# Out:
# Done in 26.84 secs
# Done in 77.62 secs

# %%
# Load metadata
metadata = CanonData(METADATA_PATH, ids=docs)
# data = metadata.data.copy()

# %%
# Add target variable
sns.countplot(metadata.data, x="label", stat="proportion")
plt.show()
ngrams = ngrams.set_index("doc").join(metadata.data["label"]).reset_index()
ngrams
# Out:
#                                                        doc  \
# 0        1816_Barthelemy-Hadot-Marie-Adelaide_La-Vierge...
# 1        1816_Barthelemy-Hadot-Marie-Adelaide_La-Vierge...
# 2        1816_Barthelemy-Hadot-Marie-Adelaide_La-Vierge...
# 3        1816_Barthelemy-Hadot-Marie-Adelaide_La-Vierge...
# 4        1816_Barthelemy-Hadot-Marie-Adelaide_La-Vierge...
# ...                                                    ...
# 4848684                1971_Veuzit-Max-du_Rien-qu'une-nuit
# 4848685                1971_Veuzit-Max-du_Rien-qu'une-nuit
# 4848686                1971_Veuzit-Max-du_Rien-qu'une-nuit
# 4848687                1971_Veuzit-Max-du_Rien-qu'une-nuit
# 4848688                1971_Veuzit-Max-du_Rien-qu'une-nuit
#
#                       token    word                         text      label
# 0            le NC de le NC     les     les regards de les agens  non-canon
# 1            le NC de le NC      le         le nom de le conseil  non-canon
# 2            le NC de le NC      la   la bienfaisance de le dieu  non-canon
# 3            le NC de le NC     les   les habitans de le royaume  non-canon
# 4            le NC de le NC     les     les fers de l' étranger  non-canon
# ...                     ...     ...                          ...        ...
# 4848684   être un ADJ NC de  serait       serait un vrai coup de  non-canon
# 4848685  être un ADJ NC que     est  est un charmant garçon que  non-canon
# 4848686  être un ADJ NC que     est        est un vrai roman que  non-canon
# 4848687     être un NC , un     est           est une bombe , un  non-canon
# 4848688     être un NC , un     est   est une plaisanterie , une  non-canon
#
# [4848689 rows x 5 columns]

# %% [markdown]
# # Train/test split
#
# We split with respect to the documents, having different document in train and test, but keeping the class distribution in train and test samples.

# %%
test_size = 0.3
random_state = 0 # For reproducibility
# Use StratifiedShuffleSplit to keep class balance
sss = StratifiedShuffleSplit(n_splits=1, test_size=test_size, random_state=random_state)
train_docs, test_docs = list(sss.split(metadata.data.index, metadata.data.label))[0]
train_docs = metadata.data.index[train_docs].tolist()
test_docs = metadata.data.index[test_docs].tolist()
print(len(train_docs), len(test_docs))

t1 = time.time()
train_motifs = ngrams[ngrams["doc"].isin(train_docs)]
test_motifs = ngrams[ngrams["doc"].isin(test_docs)]
t2 = time.time()
print(f"{t2-t1:.2f}")
# Out:
# 151 66
# 0.51

# %% [markdown]
# # Featurization (TFIDF)
#
# As we split the data in train/test, we need to compute the tfidf separately on the two samples. We get the idf on the train set and apply it on the test set, otherwise we would include information from the test set in the train set.

# %%
## Train set
t1 = time.time()
train_tfidf, model, dictionary = build_tfidf(train_motifs, normalize=False, smartirs="nfn")
t2 = time.time()
print(f"{t2-t1:.2f}")

# Test set
t1 = time.time()
test_tfidf, _, _ = build_tfidf(test_motifs, model=model, dictionary=dictionary, normalize=False, smartirs="nfn") # Use train_idf
t2 = time.time()
print(f"{t2-t1:.2f}")
# Out:
# 39.16
# 14.46

# %%
# Transform to a table with documents as indices and tokens as columns
t1 = time.time()
train_tfidf = train_tfidf.pivot_table(values="tfidf", columns="token", index="doc")
t2 = time.time()
print(f"{t2-t1:.2f}")

t1 = time.time()
test_tfidf = test_tfidf.pivot_table(values="tfidf", columns="token", index="doc")
t2 = time.time()
print(f"{t2-t1:.2f}")

# In the test set, remove new tokens and add missing ones
if set(train_tfidf.columns) != set(test_tfidf.columns):
    missing_features_in_test = pd.DataFrame(0, columns=list(set(train_tfidf.columns) - set(test_tfidf.columns)), index=test_tfidf.index)
    test_tfidf = pd.concat([test_tfidf, missing_features_in_test], axis=1)
    test_tfidf = test_tfidf[train_tfidf.columns]
    
    missing_features_in_train = list(set(test_tfidf.columns) - set(train_tfidf.columns))
    if len(missing_features_in_train):
        # Remove new features in test set (they are equal to 0 anyway)
        test_tfidf.drop(missing_features_in_train, axis=1, inplace=True)

assert train_tfidf.shape[1] == test_tfidf.shape[1]
(train_tfidf.shape, test_tfidf.shape)
# Out:
# 29.71
# 14.90
# ((151, 228404), (66, 228404))

# %%
for _ in range(100):
    plt.hist(train_tfidf.iloc[:, np.random.randint(train_tfidf.shape[-1])],
             bins=50, alpha=0.5)
plt.show()
for _ in range(100):
    plt.hist(test_tfidf.iloc[:, np.random.randint(test_tfidf.shape[-1])],
             bins=50, alpha=0.5)
plt.show()

# %% [markdown]
# ## we obtain more than 200K features, that is too many! We must introduce a criterion for feature selection.
#
# Since we know that a token which as a tfidf of 0 corresponds to non-informative tokens, we propose a simple solution solution based on the sparsity of each column of the `train_features` matrix. We define the sparsity level as the proportion of 0 in a column of a matrix ($\forall j, \operatorname{S}_j = 1/n\sum_i \operatorname{I}\{M_{ij} = 0\}$ where $n$ is the number of rows in matrix $M$ and $j$ represents a token as column). The more sparse the column of a token, the less informative is the token within the corpus, since it is more common to all documents. Then, we simply select the $n$ less sparse features.

# %%
n = 1000
sparsity = (train_tfidf == 0).sum() / len(train_tfidf)
tokens = sparsity.sort_values()[:n].index
selected_train_tfidf = train_tfidf[tokens]
selected_test_tfidf = test_tfidf[tokens]

# %% [markdown]
# ### TFIDF Normalization
#
# We normalize the TFIDF vectors of each document to have unit norm.

# %%
from sklearn.preprocessing import Normalizer

normalizer = Normalizer(norm="l2")
selected_train_tfidf = pd.DataFrame(
    normalizer.fit_transform(selected_train_tfidf), 
    columns=tokens,
    index=train_tfidf.index,
)
selected_test_tfidf = pd.DataFrame(
    normalizer.transform(selected_test_tfidf), 
    columns=tokens,
    index=test_tfidf.index,
)

x = []
for _ in range(100):
    i = np.random.randint(len(tokens))
    x.append(i)
    plt.hist(selected_train_tfidf.values[:, i],
             bins=50, alpha=0.5)
plt.show()
for i in range(100):
    plt.hist(selected_test_tfidf.values[:, x[i]],
             bins=50, alpha=0.5)
plt.show()

# %% [markdown]
# # Add control variables
#
# We include the *author*, *period*, and *gender* as control variables, encoded as one-hot features, cf `motifs.dataloader.CanonData`.

# %% [markdown]
# one_hot_features = data[["author", "period"]]
# one_hot_encoder = OneHotEncoder(handle_unknown="ignore")
#
# train_x = one_hot_encoder.fit_transform(one_hot_features.loc[train_tfidf.index])
# cols = one_hot_encoder.categories_[0].tolist() + [f"period_{i}" for i in one_hot_encoder.categories_[1]]
# train_x = pd.DataFrame(train_x.toarray(), columns=cols, index=train_tfidf.index)
# train_x["gender"] = (data["sexe"] == "female").astype(int).loc[train_tfidf.index]
#
# test_x = one_hot_encoder.transform(one_hot_features.loc[test_tfidf.index])
# test_x = pd.DataFrame(test_x.toarray(), columns=cols, index=test_tfidf.index)
# test_x["gender"] = (data["sexe"] == "female").astype(int).loc[test_tfidf.index]
#
# train_x = pd.concat([train_x, selected_train], axis=1)
# test_x = pd.concat([test_x, selected_test], axis=1)
#
# print(train_x.shape, test_x.shape)

# %%
encoded_cat, encoder = metadata.encode_categories()
# Remove gender variable (included in the author) (mostly)
encoded_cat.drop(["female", "male"], axis=1, inplace=True)

train_x = encoded_cat.loc[train_tfidf.index]
test_x = encoded_cat.loc[test_tfidf.index]

train_x = pd.concat([train_x, selected_train_tfidf], axis=1)
test_x = pd.concat([test_x, selected_test_tfidf], axis=1)
print(train_x.shape, test_x.shape)
# Out:
# (151, 1116) (66, 1116)

# %% [markdown]
# # Normalization
#
# We propose to perform a MinMax scaling of the feature in the range [0,1] to ease the interpretation of the regession coefficient.

# %%
scaler = MinMaxScaler(feature_range=(0,1))
train_features = scaler.fit_transform(train_x)
test_features = scaler.transform(test_x)

x = []
for _ in range(100):
    i = np.random.randint(train_features.shape[-1])
    x.append(i)
    plt.hist(train_features[:, i],
             bins=50, alpha=0.5)
plt.show()
for i in range(100):
    plt.hist(test_features[:, x[i]],
             bins=50, alpha=0.5)
plt.show()

# %% [markdown]
# # Target variable

# %%
train_y = metadata.data.loc[train_tfidf.index, "label"].cat.codes
test_y = metadata.data.loc[test_tfidf.index, "label"].cat.codes

# %% [markdown]
# # Fit the model

# %%
# Since we have a still a lot of features (1091) compared to the number of observations (151), we propose to use a L1 regularization to select the most important features
# It introduces one hyperparameter: C (the strength of the penalty).
# It will force many parameters to be 0, which introduce sparsity in the solution, thus it is easier to interpret
clf = LogisticRegression(solver='liblinear', penalty='l1', C=0.9, random_state=random_state)
clf.fit(train_features, train_y)

print("Train accuracy", clf.score(train_features, train_y) * 100)
print("Test accuracy", clf.score(test_features, test_y) * 100)
print("Sparisty", np.mean(clf.coef_ == 0) * 100)
# Out:
# Train accuracy 99.33774834437085
# Test accuracy 75.75757575757575
# Sparisty 95.43010752688173

# %%
train_y_proba = clf.predict_proba(train_features)
display = RocCurveDisplay.from_predictions(
    train_y,
    train_y_proba[:, 1],
    color="darkorange",
    plot_chance_level=True,
)
_ = display.ax_.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title="ROC curve on the train set",
)

test_y_proba = clf.predict_proba(test_features)
display = RocCurveDisplay.from_predictions(
    test_y,
    test_y_proba[:, 1],
    color="darkorange",
    plot_chance_level=True,
)
_ = display.ax_.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title="ROC curve on the test set",
)

# %% [markdown]
# We obtain an accuracy of 78,8% on the test set showing that we can classify realtively well whether a document is a canon or not based on the motifs and metadata. The classifier does not perfectly predict the target variable on the train set, probably because of the L1 regularization.
#
# On top the ROC curves and AUC of 0.89 on the set show that the predicted probability scores are well calibrated. Since the classes are balanced, the default probability class threshold of 0.5 is likely a good choice.

# %% [markdown]
# # Features' importance
#
#
# In theory we should keep control variables and only apply l1 regularization on the TFIDF features. We will offer a custom classifier in a later phase.

# %%
coefs = pd.Series(clf.coef_[0,:], index=train_x.columns)
selected_features = coefs[coefs != 0].sort_values(ascending=False)
print(len(selected_features))
# Separate positive and negative values
positive_values = [val if val > 0 else 0 for val in selected_features]
negative_values = [val if val < 0 else 0 for val in selected_features]

# Create a figure and axis
fig, ax = plt.subplots(figsize=(20,5))

# Plot positive values with varying shades of blue
ax.bar(range(len(positive_values)), positive_values, color=plt.cm.Blues(np.linspace(0, 1, len(positive_values)))[::-1])

# Plot negative values with varying shades of red
ax.bar(range(len(negative_values)), negative_values, color=plt.cm.Reds(np.linspace(0, 1, len(negative_values))))

# Customize the plot
ax.set_xticks(range(len(selected_features)))
ax.set_xticklabels(selected_features.index, rotation=90)
ax.set_title("Selected features coefficients")
plt.show()
# Out:
# 51

# %% [markdown]
# The lasso has selected 36 features: some motifs but also 4 authors (G. Sand, A. Dumas (père), H. de Balzac, and J. Verne), the gender variable, and 3 periods (1827-1850, 1851-1869, and 1900-1945).
#
# In our corpus, writings by G. Sand are more likely to be regarded as canonical compared to those of other authors. Similarly, A. Dumas (père) and H. de Balzac have a strong positive impact on the likelihood of a document to be classified as canonical.
#
# On the other hand, the gender of the author has a negative influence on the probability of a document to be considered canonical in our corpus. Since we encoded female as 1, writings by female authors are more liekly to be regarded as non-canonical compared to those of male authors.
#
# Finally, the periods 1827-1850 and 1900-1945 have both a positive impact on the target, while the period 1851-1869 a negative one.
#
# Let us remind that these interpretation are based on correlation only which cannot be extrapolated as causation. A priori, the gender of the author should have no impact on the etiquette of his/her writings.

# %% [markdown]
# # Error analysis

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# It seems that the type I and II errors are well balanced.

# %%
test_y_pred = clf.predict(test_features)
correct = test_y.index[test_y_pred == test_y]
errors = test_y.index[test_y_pred != test_y]

# %%
plt.hist(
    (selected_test.loc[correct] != 0).sum(axis=1) / selected_test.shape[-1], 
    alpha=0.5, 
    weights=np.ones(len(correct)) / len(correct)
)
plt.vlines(np.mean((selected_test.loc[correct] != 0).sum(axis=1) / selected_test.shape[-1]), 0, 0.22)

plt.hist(
    (selected_test.loc[errors] != 0).sum(axis=1) / selected_test.shape[-1],
    alpha=0.5,
    weights=np.ones(len(errors)) / len(errors)
)
plt.vlines(np.mean((selected_test.loc[errors] != 0).sum(axis=1) / selected_test.shape[-1]), 0, 0.22, 
           color="Orange")

# %% [markdown]
# The TFIDF features seem to be more sparse in the wrongly classified documents

# %%
fig, axs = plt.subplots(2, 1, sharex=True, sharey=True, figsize=(8, 8))
for i in range(len(selected_test.columns)):
    axs[0].hist(test_features[selected_test.index.isin(correct), -i])
for i in range(len(selected_test.columns)):
    axs[1].hist(test_features[selected_test.index.isin(errors), -i])
plt.show()

# %% [markdown]
# ## FP/FN

# %%
fp = test_y.index[(test_y_pred==1) & (test_y==0)]
fn = test_y.index[(test_y_pred==0) & (test_y==1)]
data.loc[fp]
# Out:
#                                                                                                 titre  \
# doc
# 1836_Igonette-T._Le-Valmont-de-la-jeunesse-ou-l...  Le Valmont de la jeunesse, ou le Triomphe des ...
# 1880_Ulbach-Louis_Le-Chateau-des-Epines                Le Château des Épines, par Louis Ulbach (1880)
# 1903_Leblanc-Maurice_Un-gentleman                                                        Un gentleman
# 1906_Le-Rouge-Gustave_La-Reine-des-elephants                                   La Reine des éléphants
# 1907_Vanderem-Fernand_La-victime                                                           La victime
# 1920_Leblanc-Maurice_Les-trois-yeux                                                    Les trois yeux
# 1926_Hemon-Louis_Battling-Malone-pugiliste                                 Battling Malone, pugiliste
# 1927_Leblanc-Maurice_L-Homme-a-la-peau-de-bique                            L'Homme à la peau de bique
#
#                                                                author  \
# doc
# 1836_Igonette-T._Le-Valmont-de-la-jeunesse-ou-l...       Igonette, T.
# 1880_Ulbach-Louis_Le-Chateau-des-Epines                 Ulbach, Louis
# 1903_Leblanc-Maurice_Un-gentleman                    Leblanc, Maurice
# 1906_Le-Rouge-Gustave_La-Reine-des-elephants        Le Rouge, Gustave
# 1907_Vanderem-Fernand_La-victime                    Vandérem, Fernand
# 1920_Leblanc-Maurice_Les-trois-yeux                  Leblanc, Maurice
# 1926_Hemon-Louis_Battling-Malone-pugiliste               Hémon, Louis
# 1927_Leblanc-Maurice_L-Homme-a-la-peau-de-bique      Leblanc, Maurice
#
#                                                        sexe birth_date  \
# doc
# 1836_Igonette-T._Le-Valmont-de-la-jeunesse-ou-l...  unknown       1???
# 1880_Ulbach-Louis_Le-Chateau-des-Epines                male       1822
# 1903_Leblanc-Maurice_Un-gentleman                      male       1864
# 1906_Le-Rouge-Gustave_La-Reine-des-elephants           male       1867
# 1907_Vanderem-Fernand_La-victime                       male       1864
# 1920_Leblanc-Maurice_Les-trois-yeux                    male       1864
# 1926_Hemon-Louis_Battling-Malone-pugiliste             male       1880
# 1927_Leblanc-Maurice_L-Homme-a-la-peau-de-bique        male       1864
#
#                                                    death_date  \
# doc
# 1836_Igonette-T._Le-Valmont-de-la-jeunesse-ou-l...       1???
# 1880_Ulbach-Louis_Le-Chateau-des-Epines                  1889
# 1903_Leblanc-Maurice_Un-gentleman                        1941
# 1906_Le-Rouge-Gustave_La-Reine-des-elephants             1938
# 1907_Vanderem-Fernand_La-victime                         1939
# 1920_Leblanc-Maurice_Les-trois-yeux                      1941
# 1926_Hemon-Louis_Battling-Malone-pugiliste               1913
# 1927_Leblanc-Maurice_L-Homme-a-la-peau-de-bique          1941
#
#                                                     date_publication  \
# doc
# 1836_Igonette-T._Le-Valmont-de-la-jeunesse-ou-l...              1836
# 1880_Ulbach-Louis_Le-Chateau-des-Epines                         1880
# 1903_Leblanc-Maurice_Un-gentleman                               1903
# 1906_Le-Rouge-Gustave_La-Reine-des-elephants                    1906
# 1907_Vanderem-Fernand_La-victime                                1907
# 1920_Leblanc-Maurice_Les-trois-yeux                             1920
# 1926_Hemon-Louis_Battling-Malone-pugiliste                      1926
# 1927_Leblanc-Maurice_L-Homme-a-la-peau-de-bique                 1927
#
#                                                     etiquette  period
# doc
# 1836_Igonette-T._Le-Valmont-de-la-jeunesse-ou-l...  non-canon       1
# 1880_Ulbach-Louis_Le-Chateau-des-Epines             non-canon       3
# 1903_Leblanc-Maurice_Un-gentleman                   non-canon       4
# 1906_Le-Rouge-Gustave_La-Reine-des-elephants        non-canon       4
# 1907_Vanderem-Fernand_La-victime                    non-canon       4
# 1920_Leblanc-Maurice_Les-trois-yeux                 non-canon       4
# 1926_Hemon-Louis_Battling-Malone-pugiliste          non-canon       4
# 1927_Leblanc-Maurice_L-Homme-a-la-peau-de-bique     non-canon       4

# %% [markdown]
# From the metadata, we can say that FP seems to be documents written mostly by male authors published in the period 4 that is 1900-1945. We know that on average, documents written by male and the ones published during this period have more chance to be classified as canonical by our predictor. We would probably need to include more variables to correctly classify these examples.

# %%
data.loc[fn]
# Out:
#                                                                                  titre  \
# doc
# 1825_Duras-Claire-de_Edouard                                                   Edouard
# 1855_Nerval-Gerard-de_Aurelia                                                  Aurélia
# 1858_Sand-George_Les-beaux-messieurs-de-Bois-Do...  Les beaux messieurs de Bois Dore 1
# 1895_France-Anatole_Le-Puit-de-Sainte-Claire                  Le Puit de Sainte Claire
# 1896_Schwob-Marcel_Vies-imaginaires                                   Vies imaginaires
# 1904_Verne-Jules_Un-drame-en-Livonie                               Un drame en Livonie
#
#                                                                 author  \
# doc
# 1825_Duras-Claire-de_Edouard                        Duras, Claire (de)
# 1855_Nerval-Gerard-de_Aurelia                        Nerval, Gérard de
# 1858_Sand-George_Les-beaux-messieurs-de-Bois-Do...        Sand, George
# 1895_France-Anatole_Le-Puit-de-Sainte-Claire           France, Anatole
# 1896_Schwob-Marcel_Vies-imaginaires                     Schwob, Marcel
# 1904_Verne-Jules_Un-drame-en-Livonie                      Verne, Jules
#
#                                                       sexe birth_date  \
# doc
# 1825_Duras-Claire-de_Edouard                        female       1777
# 1855_Nerval-Gerard-de_Aurelia                         male       1855
# 1858_Sand-George_Les-beaux-messieurs-de-Bois-Do...  female       1804
# 1895_France-Anatole_Le-Puit-de-Sainte-Claire          male       1844
# 1896_Schwob-Marcel_Vies-imaginaires                   male       1867
# 1904_Verne-Jules_Un-drame-en-Livonie                  male       1828
#
#                                                    death_date  \
# doc
# 1825_Duras-Claire-de_Edouard                             1828
# 1855_Nerval-Gerard-de_Aurelia                            1855
# 1858_Sand-George_Les-beaux-messieurs-de-Bois-Do...       1876
# 1895_France-Anatole_Le-Puit-de-Sainte-Claire             1924
# 1896_Schwob-Marcel_Vies-imaginaires                      1905
# 1904_Verne-Jules_Un-drame-en-Livonie                     1905
#
#                                                     date_publication  \
# doc
# 1825_Duras-Claire-de_Edouard                                    1825
# 1855_Nerval-Gerard-de_Aurelia                                   1855
# 1858_Sand-George_Les-beaux-messieurs-de-Bois-Do...              1858
# 1895_France-Anatole_Le-Puit-de-Sainte-Claire                    1895
# 1896_Schwob-Marcel_Vies-imaginaires                             1896
# 1904_Verne-Jules_Un-drame-en-Livonie                            1904
#
#                                                    etiquette  period
# doc
# 1825_Duras-Claire-de_Edouard                           canon       0
# 1855_Nerval-Gerard-de_Aurelia                          canon       2
# 1858_Sand-George_Les-beaux-messieurs-de-Bois-Do...     canon       2
# 1895_France-Anatole_Le-Puit-de-Sainte-Claire           canon       3
# 1896_Schwob-Marcel_Vies-imaginaires                    canon       3
# 1904_Verne-Jules_Un-drame-en-Livonie                   canon       4

# %% [markdown]
# From the metadata, it is difficult to interpret the False Negatives, however we notice two documents written by female authors. We know that on average, documents written by female have less chance to be classified as canonical by our predictor.

# %%
data.groupby("author")["etiquette"].value_counts()
# Out:
# author                                 etiquette
# About, Edmond                          non-canon    2
# Aimard, Gustave                        non-canon    1
# Albalat, Antoine                       non-canon    1
# Apollinaire, Guillaume                 canon        2
# Arlincourt, Charles-Victor Prévost d'  non-canon    1
#                                                    ..
# Verne, Jules                           canon        5
# Vesco, Marie Delorme, Mme Léon         non-canon    1
# Villiers de l'Isle-Adam, Auguste       canon        2
# Zola Emile                             canon        1
# Zola, Émile                            canon        2
# Name: count, Length: 113, dtype: int64

# %%
data["sexe"].value_counts()
# Out:
# sexe
# male       162
# female      51
# unknown      3
# Name: count, dtype: int64

# %%
crosstab_cluster_y = pd.crosstab(data["sexe"].astype("category"), data["etiquette"].astype("category"))
crosstab_cluster_y
# Out:
# etiquette  canon  non-canon
# sexe
# female        10         41
# male         103         59
# unknown        0          3

# %% [markdown]
# # Rolling window

# %%
train_features.shape
# Out:
# (151, 1094)

# %%
from motifs.utils import build_window_corpus
or_ngrams = pd.read_csv(NGRAMS_PATH, index_col=0)
docs = list(set(or_ngrams.doc.unique()))

# %%
seq_length = 100
doc = "1842_Balzac-Honore-de_La-Maison-du-chat-qui-pelote"
window = build_window_corpus(or_ngrams[or_ngrams["doc"] == doc], seq_length)
window["doc"] = window["doc"] + "_" + window["window"].astype(str)
window
# Out:
#       window                           text                 token  \
# 0          0                – Ah ! madame ,         – INTJ ! NC ,
# 1          0        Ah ! madame , répliqua       INTJ ! NC , VPS
# 2          0        ! madame , répliqua le         ! NC , VPS le
# 3          0  madame , répliqua le docteur        NC , VPS le NC
# 4          0       , répliqua le docteur ,         , VPS le NC ,
# ...      ...                            ...                   ...
# 9695    9600             dire un seul mot :       INF un ADJ NC :
# 9696    9600                un seul mot : –         un ADJ NC : –
# 9697    9600              seul mot : – Vous       ADJ NC : – vous
# 9698    9600              mot : – Vous avez     NC : – vous avoir
# 9699    9600            : – Vous avez juré  : – vous avoir PROPN
#
#                                                     doc
# 0     1842_Balzac-Honore-de_La-Maison-du-chat-qui-pe...
# 1     1842_Balzac-Honore-de_La-Maison-du-chat-qui-pe...
# 2     1842_Balzac-Honore-de_La-Maison-du-chat-qui-pe...
# 3     1842_Balzac-Honore-de_La-Maison-du-chat-qui-pe...
# 4     1842_Balzac-Honore-de_La-Maison-du-chat-qui-pe...
# ...                                                 ...
# 9695  1842_Balzac-Honore-de_La-Maison-du-chat-qui-pe...
# 9696  1842_Balzac-Honore-de_La-Maison-du-chat-qui-pe...
# 9697  1842_Balzac-Honore-de_La-Maison-du-chat-qui-pe...
# 9698  1842_Balzac-Honore-de_La-Maison-du-chat-qui-pe...
# 9699  1842_Balzac-Honore-de_La-Maison-du-chat-qui-pe...
#
# [9700 rows x 4 columns]

# %%
## Train set
t1 = time.time()
tfidf, _, _ = build_tfidf(window, model=model, dictionary=dictionary)
t2 = time.time()
print(f"{t2-t1:.2f}")
# Out:
# 11.56

# %%
tfidf = tfidf.pivot_table(index="doc", columns="token", values="tfidf")
tfidf = tfidf[selected_train.columns]
tfidf = pd.DataFrame(
    normalizer.transform(tfidf), 
    columns=tfidf.columns, 
    index=tfidf.index,
)

# %%
# Out:
# token                                               NC ADJ de le NC  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# ...                                                             ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
#
# token                                               NC , le NC de  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# ...                                                           ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
#
# token                                               de le NC de le  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# ...                                                            ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
#
# token                                               le NC de NC ,  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...       0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...       0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...       0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...       0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...       0.000000
# ...                                                           ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...       0.005138
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...       0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...       0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...       0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...       0.000000
#
# token                                               le NC de PROPN ,  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...          0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...          0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...          0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...          0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...          0.000000
# ...                                                              ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...          0.005138
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...          0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...          0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...          0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...          0.000000
#
# token                                               le NC de son NC  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...         0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...         0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...         0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...         0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...         0.000000
# ...                                                             ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...         0.005138
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...         0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...         0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...         0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...         0.000000
#
# token                                               le NC de un NC  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# ...                                                            ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
#
# token                                               PROPN le NC de le  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.00000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.00000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.00000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.00000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.00000
# ...                                                               ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.00000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.00000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.00000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.00948
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.00000
#
# token                                               NC de le NC .  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# ...                                                           ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
#
# token                                               , le NC de le  ...  \
# doc                                                                ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
# ...                                                           ...  ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
#
# token                                               PROPN un ADJ NC de  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.521868
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.000000
# ...                                                                ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.000000
#
# token                                               ADJ NC , un NC  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# ...                                                            ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
#
# token                                               VIMP un NC ADJ ,  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# ...                                                              ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
#
# token                                               NC , son NC ADJ  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# ...                                                             ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
#
# token                                               INF à le NC .  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# ...                                                           ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
#
# token                                               il VIMP le NC de  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# ...                                                              ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
#
# token                                               dans un ADJ NC de  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# ...                                                               ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
#
# token                                               le NC , en NC  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# ...                                                           ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
#
# token                                               NC en NC de NC  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# ...                                                            ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
#
# token                                               le NC , et je
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# ...                                                           ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
#
# [97 rows x 1000 columns]

# %%
x = pd.DataFrame(
    np.repeat(test_x.loc[[doc]].iloc[:,:-selected_train.shape[-1]], len(tfidf), axis=0),
    index=tfidf.index
)
x = pd.DataFrame(
    np.zeros((len(tfidf), test_x.shape[-1])),
    index=tfidf.index,
    columns=train_x.columns
)

x.loc[:, tfidf.columns] = tfidf.values
x
# Out:
#                                                     About, Edmond  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# ...                                                           ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
#
#                                                     Aimard, Gustave  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# ...                                                             ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
#
#                                                     Albalat, Antoine  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# ...                                                              ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
#
#                                                     Apollinaire, Guillaume  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                     0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                     0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                     0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                     0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                     0.0
# ...                                                                    ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                     0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                     0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                     0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                     0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                     0.0
#
#                                                     Arlincourt, Charles-Victor Prévost d'  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                                    0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                                    0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                                    0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                                    0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                                    0.0
# ...                                                                                   ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                                    0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                                    0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                                    0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                                    0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                                    0.0
#
#                                                     Balzac, Honoré de  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# ...                                                               ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
#
#                                                     Barrès, Maurice  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# ...                                                             ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
#
#                                                     Barthélemy-Hadot, Marie-Adélaïde  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                               0.0
# ...                                                                              ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                               0.0
#
#                                                     Bernanos, Georges  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# ...                                                               ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
#
#                                                     Bourget, Paul  ...  \
# doc                                                                ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
# ...                                                           ...  ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0  ...
#
#                                                     PROPN un ADJ NC de  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.521868
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.000000
# ...                                                                ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.000000
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.000000
#
#                                                     ADJ NC , un NC  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# ...                                                            ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
#
#                                                     VIMP un NC ADJ ,  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# ...                                                              ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
#
#                                                     NC , son NC ADJ  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# ...                                                             ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...              0.0
#
#                                                     INF à le NC .  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# ...                                                           ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
#
#                                                     il VIMP le NC de  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# ...                                                              ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...               0.0
#
#                                                     dans un ADJ NC de  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# ...                                                               ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...                0.0
#
#                                                     le NC , en NC  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# ...                                                           ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
#
#                                                     NC en NC de NC  \
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# ...                                                            ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...             0.0
#
#                                                     le NC , et je
# doc
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# ...                                                           ...
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
# 1842_Balzac-Honore-de_La-Maison-du-chat-qui-pel...            0.0
#
# [97 rows x 1094 columns]

# %%
probas = clf.predict_proba(x)[:,1]
plt.plot(probas)
# Out:
# /Users/brunospilak/miniconda3/envs/pymotifs/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
